# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data2=pd.read_csv("Shark Tank India Dataset.csv")

# %%
data2.head(10)
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
# 2               1             3  Heart up my Sleeves
# 3               2             4           Tagz Foods
# 4               2             5       Head and Heart
# 5               2             6         Agro tourism
# 6               3             7          Qzense Labs
# 7               3             8            Peeschute
# 8               3             9                 NOCD
# 9               4            10                Cosiq
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
# 2                             Detachable Sleeves     1                25.0
# 3                           Healthy Potato Chips     1                70.0
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   episode_number         117 non-null    int64
#  1   pitch_number           117 non-null    int64
#  2   brand_name             117 non-null    object
#  3   idea                   117 non-null    object
#  4   deal                   117 non-null    int64
#  5   pitcher_ask_amount     117 non-null    float64
#  6   ask_equity             117 non-null    float64
#  7   ask_valuation          117 non-null    float64
#  8   deal_amount            117 non-null    float64
#  9   deal_equity            117 non-null    float64
#  10  deal_valuation         117 non-null    float64
#  11  ashneer_present        117 non-null    int64
#  12  anupam_present         117 non-null    int64
#  13  aman_present           117 non-null    int64
# ...

# %%
data2.shape
# Out:
# (117, 28)

# %%
data2.isnull().sum()
# Out:
# episode_number           0
# pitch_number             0
# brand_name               0
# idea                     0
# deal                     0
# pitcher_ask_amount       0
# ask_equity               0
# ask_valuation            0
# deal_amount              0
# deal_equity              0
# deal_valuation           0
# ashneer_present          0
# anupam_present           0
# aman_present             0
# namita_present           0
# vineeta_present          0
# peyush_present           0
# ghazal_present           0
# ashneer_deal             0
# anupam_deal              0
# aman_deal                0
# namita_deal              0
# vineeta_deal             0
# peyush_deal              0
# ghazal_deal              0
# total_sharks_invested    0
# amount_per_shark         0
# equity_per_shark         0
# dtype: int64

# %%
total_num_pitches=len(data2.episode_number)
total_num_pitches
# Out:
# 117

# %%
total_num_epi=data2.episode_number.nunique()
total_num_epi
# Out:
# 35

# %%
import matplotlib.pyplot as plt
plt.bar(['total number of episode'],total_num_epi,color='Turquoise', edgecolor='white', width=0.6)

# Label the x and y axes
plt.xlabel('X Axis')
plt.ylabel('total number of episode')
plt.title('total number of episode', fontsize=16, fontweight='bold', color='gray')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# %%
import matplotlib.pyplot as plt
plt.bar(['total number of piches'],total_num_pitches,color='teal', edgecolor='white', width=0.6)

# Label the x and y axes
plt.xlabel('X Axis')
plt.ylabel('total number of pitches')
plt.title('total number of pitches', fontsize=16, fontweight='bold', color='gray')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().set_facecolor('#F0F0F0')

# %%
data2.deal.value_counts()
# Out:
# deal
# 1    65
# 0    52
# Name: count, dtype: int64

# %%
sns.countplot(x='deal',data=data2)
# Out:
# <Axes: xlabel='deal', ylabel='count'>

# %%
top_10=data2['pitcher_ask_amount'].nlargest(10)
print(top_10)
# Out:
# 30     30000.0
# 96       300.0
# 103      200.0
# 50       150.0
# 80       150.0
# 59       125.0
# 60       120.0
# 6        100.0
# 12       100.0
# 17       100.0
# Name: pitcher_ask_amount, dtype: float64

# %%
plt.figure(figsize=(20,20))
sns.countplot(x="pitcher_ask_amount",data=data2)
plt.show()

# %%
print(data2['aman_present'].value_counts())
# Out:
# aman_present
# 1    98
# 0    19
# Name: count, dtype: int64

# %%
print(data2['anupam_present'].value_counts())
# Out:
# anupam_present
# 1    117
# Name: count, dtype: int64

# %%
print(data2['ashneer_present'].value_counts())
# Out:
# ashneer_present
# 1    98
# 0    19
# Name: count, dtype: int64

# %%
print(data2['ghazal_present'].value_counts())
# Out:
# ghazal_present
# 0    91
# 1    26
# Name: count, dtype: int64

# %%
print(data2['namita_present'].value_counts())
# Out:
# namita_present
# 1    106
# 0     11
# Name: count, dtype: int64

# %%
print(data2['peyush_present'].value_counts())
# Out:
# peyush_present
# 1    88
# 0    29
# Name: count, dtype: int64

# %%
print(data2['vineeta_present'].value_counts())
# Out:
# vineeta_present
# 1    66
# 0    51
# Name: count, dtype: int64

# %%
ls=['aman_present','anupam_present','ashneer_present','ghazal_present','namita_present','peyush_present','vineeta_present']
ls
# Out:
# ['aman_present',
#  'anupam_present',
#  'ashneer_present',
#  'ghazal_present',
#  'namita_present',
#  'peyush_present',
#  'vineeta_present']

# %%
for i in ls:
    sns.countplot(x=i, data=data2)
    print()

# %%
top_10_valuation=data2['ask_valuation'].nlargest(10)
print(top_10_valuation)
# Out:
# 30     120000.0
# 6       40000.0
# 96      30000.0
# 12      10000.0
# 17      10000.0
# 55      10000.0
# 59      10000.0
# 72      10000.0
# 87      10000.0
# 113     10000.0
# Name: ask_valuation, dtype: float64

# %%
top_10_valuation_lowest=data2['ask_valuation'].nsmallest(10)
print(top_10_valuation_lowest)
# Out:
# 85       0.01
# 14      50.00
# 44     100.00
# 77     200.00
# 2      250.00
# 1      266.67
# 32     300.00
# 57     300.00
# 76     300.00
# 106    400.00
# Name: ask_valuation, dtype: float64

# %%
anupam_presents =len(data2[data2.anupam_present==1])
ashneer_presents = len(data2[data2.ashneer_present==1])
aman_presents =len(data2[data2.aman_present==1])                            
namita_presents =len(data2[data2.namita_present==1])                            
vineeta_presents= len(data2[data2.vineeta_present==1])                            
peyush_presents=len(data2[data2.peyush_present==1])
ghazal_presents= len(data2[data2.ghazal_present==1])

# %%
presents = [anupam_presents,aman_presents,peyush_presents,ghazal_presents,vineeta_presents,namita_presents]
name=["anupam","aman","peyush","ghazal","vineeta","namita"]
plt.bar(name,presents)
plt.title('Number of pitches heard', fontsize=16, fontweight='bold', color='gray')
# Out:
# Text(0.5, 1.0, 'Number of pitches heard')

# %%
plt.pie(presents, labels=name, autopct='%1.1f%%')
plt.title('Number of pitches heard', fontsize=16, fontweight='bold', color='gray')
plt.axis('equal')
plt.legend(title="Name", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))
plt.tight_layout()
plt.show()

# %%
aman_invested=len(data2[data2.aman_deal==1])
anupam_invested=len(data2[data2.anupam_deal==1])
ashneer_invested=len(data2[data2.ashneer_deal==1])
ghazal_invested=len(data2[data2.ghazal_deal==1])
namita_invested=len(data2[data2.namita_deal==1])
peyush_invested=len(data2[data2.peyush_deal==1])
vineeta_invested=len(data2[data2.vineeta_deal==1])

# %%
fig =plt.figure(figsize=(10,5))
invested=[aman_invested,anupam_invested,ashneer_invested,ghazal_invested,namita_invested,peyush_invested,vineeta_invested]
names=['Aman','Anupam','Ashneer','Ghazal','Namita','Peyush','Vineeta']
plt.bar(names,invested,color='dodgerblue',width=0.5)
plt.xlabel("Candidate Name")
plt.ylabel("Candidate Invested")
plt.title("Candidate Invested vs Name")
plt.show()

# %%
plt.pie(invested, labels=names, autopct='%1.1f%%')
plt.title('Number of pitches heard', fontsize=16, fontweight='bold', color='gray')
plt.axis('equal')
plt.legend(title="Name", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))
plt.tight_layout()
plt.show()

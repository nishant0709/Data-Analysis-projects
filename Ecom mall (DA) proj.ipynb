# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('ecom.csv')

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.apply(lambda x: len(x.unique()))
# Out:
# Item_Identifier              1559
# Item_Weight                   416
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     4
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %%
df.apply(lambda x: (x.nunique()))
# Out:
# Item_Identifier              1559
# Item_Weight                   415
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     3
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %%
df.isna().sum() #df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
ecom_df_numerical=df.select_dtypes(exclude=[object])

# %%
ecom_df_category=df.select_dtypes(include=[object])

# %%
cat_col=[]
for x in df.dtypes.index:
    if df.dtypes[x]=='object':
        cat_col.append(x)
cat_col
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
ecom_df_category.shape
# Out:
# (8523, 7)

# %%
ecom_df_numerical.shape
# Out:
# (8523, 5)

# %%
ecom_df_category.columns
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
ecom_df_numerical.columns
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
cat_col.remove('Item_Identifier')
cat_col.remove('Outlet_Identifier')
cat_col
# Out:
# ['Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %%
df['Item_Type'].value_counts()
# Out:
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: count, dtype: int64

# %%
df['Outlet_Size'].value_counts()
# Out:
# Outlet_Size
# Medium    2793
# Small     2388
# High       932
# Name: count, dtype: int64

# %%
df['Outlet_Location_Type'].value_counts()
# Out:
# Outlet_Location_Type
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: count, dtype: int64

# %%
df['Outlet_Type'].value_counts()
# Out:
# Outlet_Type
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: count, dtype: int64

# %%
sns.countplot(x='Item_Fat_Content',data=df,palette='husl')
# Out:
# <Axes: xlabel='Item_Fat_Content', ylabel='count'>

# %%
sns.countplot(x='Item_Type',data=df,palette='husl')
# Out:
# <Axes: xlabel='Item_Type', ylabel='count'>

# %%
sns.countplot(x='Outlet_Size',data=df,palette='husl')
# Out:
# <Axes: xlabel='Outlet_Size', ylabel='count'>

# %%
sns.countplot(x='Outlet_Location_Type',data=df,palette='husl')
# Out:
# <Axes: xlabel='Outlet_Location_Type', ylabel='count'>

# %%
sns.countplot(x='Outlet_Type',data=df,palette='husl')
# Out:
# <Axes: xlabel='Outlet_Type', ylabel='count'>

# %%
df['Item_Weight'].describe()
# Out:
# count    7060.000000
# mean       12.857645
# std         4.643456
# min         4.555000
# 25%         8.773750
# 50%        12.600000
# 75%        16.850000
# max        21.350000
# Name: Item_Weight, dtype: float64

# %%
df["Item_Weight"]=df['Item_Weight'].fillna(df['Item_Weight'].mean())

# %%
df['Item_Weight'].describe()
# Out:
# count    8523.000000
# mean       12.857645
# std         4.226124
# min         4.555000
# 25%         9.310000
# 50%        12.857645
# 75%        16.000000
# max        21.350000
# Name: Item_Weight, dtype: float64

# %%
df['Outlet_Size']=df["Outlet_Size"].fillna(df['Outlet_Size'].mode()[0])

# %%
df['Outlet_Size'].isnull().sum()
# Out:
# 0

# %%
sum(df['Item_Visibility']==0)
# Out:
# 526

# %%
df['Item_Visibility'].mean()
# Out:
# 0.06613202877895108

# %%
df.loc[:,'Item_Visibility'].replace([0],[df['Item_Visibility'].mean()],inplace=True)

# %%
sum(df['Item_Visibility']==0)
# Out:
# 0

# %%
df['Item_Fat_Content']=df['Item_Fat_Content'].replace({'LF':'Low Fat','reg':'Regular','low fat':'Low Fat'})
df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5517
# Regular    3006
# Name: count, dtype: int64

# %%
df['Item_Identifier'].head(20)
# Out:
# 0     FDA15
# 1     DRC01
# 2     FDN15
# 3     FDX07
# 4     NCD19
# 5     FDP36
# 6     FDO10
# 7     FDP10
# 8     FDH17
# 9     FDU28
# 10    FDY07
# 11    FDA03
# 12    FDX32
# 13    FDS46
# 14    FDF32
# 15    FDP49
# 16    NCB42
# 17    FDP49
# 18    DRI11
# 19    FDU02
# Name: Item_Identifier, dtype: object

# %%
df["New_Item_Type"]=df['Item_Identifier'].apply(lambda x: x[:2])
df['New_Item_Type']
# Out:
# 0       FD
# 1       DR
# 2       FD
# 3       FD
# 4       NC
#         ..
# 8518    FD
# 8519    FD
# 8520    NC
# 8521    FD
# 8522    DR
# Name: New_Item_Type, Length: 8523, dtype: object

# %%
df['New_Item_Type']=df['New_Item_Type'].map({'FD':'Food','NC':'Non-Consumable','DR':'Drinks'})
df['New_Item_Type'].value_counts()
# Out:
# New_Item_Type
# Food              6125
# Non-Consumable    1599
# Drinks             799
# Name: count, dtype: int64

# %%
size = df['New_Item_Type'].value_counts()
labels = ["Food","Non-Consumable","Drinks"]
colors = ['orange', 'yellow',"cyan"]
explode = [0, 0.1,0.2]
, 
plt.rcParams['figure.figsize'] = (7, 7)
plt.style.use('dark_background')
plt.pie(size, colors = colors, labels = labels, shadow = True, explode = explode, autopct = '%.2f%%')
plt.title('Food Category Analysis', fontsize = 20)
#plt.axis("on")
plt.legend()
plt.show()

# %%
df['New_Item_Type'].value_counts()
# Out:
# New_Item_Type
# Food              6125
# Non-Consumable    1599
# Drinks             799
# Name: count, dtype: int64

# %%
df.loc[df['New_Item_Type']=='Non-Consumable','Item_Fat_Content']='Non-Edible'

# %%
df["Item_Fat_Content"].value_counts()
# Out:
# Item_Fat_Content
# Low Fat       3918
# Regular       3006
# Non-Edible    1599
# Name: count, dtype: int64

# %%
df['New_Item_Type'].value_counts()
# Out:
# New_Item_Type
# Food              6125
# Non-Consumable    1599
# Drinks             799
# Name: count, dtype: int64

# %%
df["New_Item_Type"]
# Out:
# 0                 Food
# 1               Drinks
# 2                 Food
# 3                 Food
# 4       Non-Consumable
#              ...
# 8518              Food
# 8519              Food
# 8520    Non-Consumable
# 8521              Food
# 8522            Drinks
# Name: New_Item_Type, Length: 8523, dtype: object

# %%
df["Item_Fat_Content"]
# Out:
# 0          Low Fat
# 1          Regular
# 2          Low Fat
# 3          Regular
# 4       Non-Edible
#            ...
# 8518       Low Fat
# 8519       Regular
# 8520    Non-Edible
# 8521       Regular
# 8522       Low Fat
# Name: Item_Fat_Content, Length: 8523, dtype: object

# %%
df['Outlet_Years']=2013-df['Outlet_Establishment_Year']

# %%
df['Outlet_Years']
# Out:
# 0       14
# 1        4
# 2       14
# 3       15
# 4       26
#         ..
# 8518    26
# 8519    11
# 8520     9
# 8521     4
# 8522    16
# Name: Outlet_Years, Length: 8523, dtype: int64

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.066132
# 4           NCD19         8.93       Non-Edible         0.066132
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
sns.distplot(df['Item_Weight'])
# Out:
# C:\Users\nisha\AppData\Local\Temp\ipykernel_11436\1001071604.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Item_Weight'])
# C:\Users\nisha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Item_Weight', ylabel='Density'>

# %%
sns.distplot(df['Item_Visibility'])
# Out:
# C:\Users\nisha\AppData\Local\Temp\ipykernel_11436\852521860.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Item_Visibility'])
# C:\Users\nisha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Item_Visibility', ylabel='Density'>

# %%
sns.distplot(df['Item_MRP'])
# Out:
# C:\Users\nisha\AppData\Local\Temp\ipykernel_11436\3329567677.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Item_MRP'])
# C:\Users\nisha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Item_MRP', ylabel='Density'>

# %%
sns.distplot(df['Item_Outlet_Sales'])
# Out:
# C:\Users\nisha\AppData\Local\Temp\ipykernel_11436\1265494514.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Item_Outlet_Sales'])
# C:\Users\nisha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
#log Transformation
df['Item_Outlet_Sales']=np.log(1+df['Item_Outlet_Sales'])

# %%
sns.distplot(df['Item_Outlet_Sales'])
# Out:
# C:\Users\nisha\AppData\Local\Temp\ipykernel_11436\1265494514.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Item_Outlet_Sales'])
# C:\Users\nisha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
#Coorelation Matrix
corr=df.corr(numeric_only=True)
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.corr(numeric_only=True)
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.017450  0.024756
# Item_Visibility              -0.017450         1.000000 -0.005259
# Item_MRP                      0.024756        -0.005259  1.000000
# Outlet_Establishment_Year    -0.008301        -0.078355  0.005020
# Item_Outlet_Sales             0.008059        -0.202466  0.509886
# Outlet_Years                  0.008301         0.078355 -0.005020
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales  \
# Item_Weight                                -0.008301           0.008059
# Item_Visibility                            -0.078355          -0.202466
# Item_MRP                                    0.005020           0.509886
# Outlet_Establishment_Year                   1.000000           0.077032
# Item_Outlet_Sales                           0.077032           1.000000
# ...

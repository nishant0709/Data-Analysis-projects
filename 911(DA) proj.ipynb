# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %%
data1=pd.read_csv('911.csv')

# %%
data1.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 17:40:01         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 17:40:01   LOWER POTTSGROVE
#
#                          addr  e
# ...

# %%
data1.shape
# Out:
# (99492, 9)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99492 entries, 0 to 99491
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lat        99492 non-null  float64
#  1   lng        99492 non-null  float64
#  2   desc       99492 non-null  object
#  3   zip        86637 non-null  float64
#  4   title      99492 non-null  object
#  5   timeStamp  99492 non-null  object
#  6   twp        99449 non-null  object
#  7   addr       98973 non-null  object
#  8   e          99492 non-null  int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 6.8+ MB

# %%
data1.isnull().sum()
# Out:
# lat              0
# lng              0
# desc             0
# zip          12855
# title            0
# timeStamp        0
# twp             43
# addr           519
# e                0
# dtype: int64

# %%
data1['zip'].value_counts()
# Out:
# zip
# 19401.0    6979
# 19464.0    6643
# 19403.0    4854
# 19446.0    4748
# 19406.0    3174
#            ...
# 19119.0       1
# 77316.0       1
# 19457.0       1
# 19107.0       1
# 19127.0       1
# Name: count, Length: 104, dtype: int64

# %%
data1['twp'].value_counts()
# Out:
# twp
# LOWER MERION     8443
# ABINGTON         5977
# NORRISTOWN       5890
# UPPER MERION     5227
# CHELTENHAM       4575
#                  ...
# BRYN ATHYN        173
# SALFORD           163
# GREEN LANE         51
# PHILA COUNTY       43
# LEHIGH COUNTY      30
# Name: count, Length: 68, dtype: int64

# %%
data1['title'].nunique()
# Out:
# 110

# %%
data1['reason']=data1['title'].apply(lambda x: x.split(':')[0])

# %%
data1['reason'].value_counts()
# Out:
# reason
# EMS        48877
# Traffic    35695
# Fire       14920
# Name: count, dtype: int64

# %%
sns.countplot(x=data1['reason'])
# Out:
# <Axes: xlabel='reason', ylabel='count'>

# %%
data1['timeStamp']=pd.to_datetime(data1['timeStamp'])

# %%
data1['Hour']=data1['timeStamp'].apply(lambda x:x.hour)
data1['Month']=data1['timeStamp'].apply(lambda x:x.month)
data1['Day of Week']=data1['timeStamp'].apply(lambda x:x.dayofweek)

# %%
dmap={0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}
data1['Day of Week']=data1['Day of Week'].map(dmap)

# %%
data1.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title           timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY 2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY 2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK 2015-12-10 17:40:00         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY 2015-12-10 17:40:01         NORRISTOWN
# 4      NaN           EMS: DIZZINESS 2015-12-10 17:40:01   LOWER POTTSGROVE
#
# ...

# %%
sns.countplot(x="Day of Week",data=data1,hue="reason",palette="Greens")
plt.legend(bbox_to_anchor=(1,1),loc=2,borderaxespad=0.)

# %%
sns.countplot(x='Month',data=data1,hue='reason',palette='viridis')
plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0)

# %%
bymonth=data1.groupby('Month').count()
bymonth.head(10)
# Out:
#          lat    lng   desc    zip  title  timeStamp    twp   addr      e  \
# Month
# 1      13205  13205  13205  11527  13205      13205  13203  13096  13205
# 2      11467  11467  11467   9930  11467      11467  11465  11396  11467
# 3      11101  11101  11101   9755  11101      11101  11092  11059  11101
# 4      11326  11326  11326   9895  11326      11326  11323  11283  11326
# 5      11423  11423  11423   9946  11423      11423  11420  11378  11423
# 6      11786  11786  11786  10212  11786      11786  11777  11732  11786
# 7      12137  12137  12137  10633  12137      12137  12133  12088  12137
# 8       9078   9078   9078   7832   9078       9078   9073   9025   9078
# 12      7969   7969   7969   6907   7969       7969   7963   7916   7969
#
#        reason   Hour  Day of Week
# Month
# 1       13205  13205        13205
# 2       11467  11467        11467
# 3       11101  11101        11101
# 4       11326  11326        11326
# 5       11423  11423        11423
# ...

# %%
bymonth['twp'].plot()
# Out:
# <Axes: xlabel='Month'>

# %%
sns.lmplot(x='Month',y='twp',data=bymonth.reset_index(),ci=None)

# %%
data1['Date']=data1['timeStamp'].apply(lambda t:t.date())

# %%
data1.groupby('Date').count()['twp'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data1[data1['reason']=='Traffic'].groupby('Date').count()['twp'].plot()
plt.title('Traffic')
plt.tight_layout()

# %%
data1[data1['reason']=='Fire'].groupby('Date').count()['twp'].plot()
plt.title('Fire')
plt.tight_layout()

# %%
data1[data1['reason']=='EMS'].groupby('Date').count()['twp'].plot()
plt.title('EMS')
plt.tight_layout()
